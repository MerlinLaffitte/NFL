# %%
import pandas as pd

# %%
df = pd.read_csv("./data/player_punt_data.csv")
df.head(10)
# Out:
#    GSISID Number Position
# 0   32069     36       SS
# 1   30095     11       WR
# 2   31586     22       FS
# 3   29520     35       SS
# 4   30517     51      OLB
# 5   32697     36       FS
# 6   32250     18       WR
# 7   27978     54      ILB
# 8   31666     44      OLB
# 9   27791     44       RB

# %%
df = pd.read_csv("./data/video_review.csv")

# %%
df
# Out:
#     Season_Year  GameKey  PlayID  GSISID Player_Activity_Derived  \
# 0          2016        5    3129   31057                Tackling
# 1          2016       21    2587   29343                 Blocked
# 2          2016       29     538   31023                Tackling
# 3          2016       45    1212   33121                Tackling
# 4          2016       54    1045   32444                 Blocked
# 5          2016       60     905   30786                Blocking
# 6          2016      144    2342   32410                Blocking
# 7          2016      149    3663   28128                Blocking
# 8          2016      189    3509   27595                 Tackled
# 9          2016      218    3468   28987                 Blocked
# 10         2016      231    1976   32214                 Blocked
# 11         2016      234    3278   28620                Tackling
# 12         2016      266    2902   23564                 Tackled
# ...
